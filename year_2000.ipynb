# %%
import pandas as pd

# %%
rec_2000 = pd.read_csv('./receiving/2000.csv', index_col=0)
rec_2000
# Out:
#                Player           School      Conf   G  Rec   Yds   Avg  TD  \
# 1       Derrick Lewis  San Diego State       MWC  11   31   802  23.6   3
# 2     Robert Prescott     Oregon State    Pac-10   9   28   668  23.0   4
# 3        Chad Johnson     Oregon State    Pac-10  12   37   801  20.5   8
# 4    Marcellus Harris    East Carolina      CUSA  10   23   568  19.6   5
# 5        Snoop Minnis    Florida State       ACC  12   63  1340  21.3  11
# ..                ...              ...       ...  ..  ...   ...   ...  ..
# 387    Jacquis Walker   Arkansas State  Big West  11   25   323   6.1   4
# 388       Jameel Cook         Illinois   Big Ten  10   34   433   5.2   1
# 389    Duane Epperson             Duke       ACC  11   23   546   4.1   0
# 390    Shaud Williams       Texas Tech    Big 12  12   48   522   5.1   2
# 391    Ricky Williams       Texas Tech    Big 12  12   52   649   3.6   7
#
#        Att  Plays
# 1      3.0     34
# 2      1.0     29
# 3      2.0     39
# ...

# %%
rush_2000 = pd.read_csv('./rushing/2000.csv', index_col=0)
rush_2000
# Out:
#                  Player                  School      Conf   G  Att   Yds  Avg  \
# 1          Kenton Keith        New Mexico State  Big West  11  109   865  7.5
# 2       Levron Williams                 Indiana   Big Ten  10  116   937  6.9
# 3    Correll Buckhalter                Nebraska    Big 12  11  106   835  7.5
# 4       Deonce Whitaker          San Jose State       WAC  10  224  1614  7.1
# 5           Dwone Hicks  Middle Tennessee State       Ind  11  186  1458  7.1
# ..                  ...                     ...       ...  ..  ...   ...  ...
# 257    Josh Blankenship                   Tulsa       WAC  12   81   -19 -0.2
# 258           Andy Sahm     Bowling Green State       MAC  11   81   -76 -0.9
# 259       Philip Rivers    North Carolina State       ACC  11   73   -68 -0.9
# 260           D. Bryant                    Duke       ACC  11   79   -67 -0.8
# 261      Jason McKinley                 Houston      CUSA  11   73  -131 -1.8
#
#      TD   Rec  Plays
# ...

# %%
pass_2000 = pd.read_csv('./passing/2000.csv')
pass_2000
# Out:
#     Unnamed: 0          Player            School      Conf   G  Cmp  Att  \
# 0            1    Chris Weinke     Florida State       ACC  12  266   30
# 1            2  Bart Hendricks       Boise State  Big West  11  210   85
# 2            3     John Turman              Pitt  Big East  11  128   65
# 3            4  Casey Printers   Texas Christian       WAC  11  102   84
# 4            5    Rex Grossman           Florida       SEC  11  131   27
# ..         ...             ...               ...       ...  ..  ...  ...
# 89          94   Walter Church  Eastern Michigan       MAC  11  238   27
# 90          95  Tavares Bolden            Toledo       MAC  11  161   73
# 91          96      Jay Stoner           Wyoming       MWC   9  171   53
# 92          97       D. Bryant              Duke       ACC  11  129   79
# 93          98   Zach Williams        Kent State       MAC   9  114   32
#
#      Pct  Yds  Y/A  AY/A  TD  Int   Rate  Avg
# ...

# %%
pass_2000.sort_values('Yds', ascending=False)
# Out:
#                Player           School     Conf   G  Cmp  Att   Pct   Yds  \
# 75  Antwaan Randle El          Indiana  Big Ten  11  133  218  48.0  1270
# 18   Woodrow Dantzler          Clemson      ACC  11  122  172  57.5   947
# 6       Mike Thiessen        Air Force      MWC  11  112  179  57.4   713
# 8        Jason Thomas             UNLV      MWC  11  106  138  52.7   599
# 59  Marquel Blackwell    South Florida      Ind  11  171  128  57.8   566
# ..                ...              ...      ...  ..  ...  ...   ...   ...
# 23        Matt Newton   Colorado State      MWC  11  198   39  59.3  -151
# 33        Lon Sheriff  San Diego State      MWC  10  155   54  53.4  -162
# 11     Jonathan Smith     Oregon State   Pac-10  12  170   56  50.3  -165
# 96         Jay Stoner          Wyoming      MWC   9  171   53  62.2  -175
# 88         Joe Freedy          Buffalo      MAC  11  184   55  54.4  -190
#
#     Y/A  AY/A  TD  Int   Rate  Avg
# 75  6.4   4.9  13   14  103.9  5.8
# ...

# %%
rec_2003 = pd.read_csv('./receiving/2003.csv')

# %%
rec_2004 = pd.read_csv('./receiving/2004.csv')

# %%
rec_2005 = pd.read_csv('./receiving/2005.csv')

# %%
rec_2006 = pd.read_csv('./receiving/2006.csv')

# %%
2000_years = [rec_2000, rec_2001, rec_2002, rec_2003, rec_2004, rec_2005, rec_2006]

# %%
result = pd.concat(receiving_years)
