# %%
import requests
import lxml.html as lh
import pandas as pd

# %% [markdown]
# ### 2000

# %%
url='https://www.sports-reference.com/cfb/years/2000-rushing.html'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[1]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Rk"
# 2:"Player"
# 3:"School"
# 4:"Conf"
# 5:"G"
# 6:"Att"
# 7:"Yds"
# 8:"Avg"
# 9:"TD"
# 10:"Rec"
# 11:"Yds"
# 12:"Avg"
# 13:"TD"
# 14:"Plays"
# 15:"Yds"
# 16:"Avg"
# 17:"TD"

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=17:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df
# Out:
#       Rk              Player                School      Conf   G  Att   Yds  \
# 0     Rk              Player                School      Conf   G  Att   Yds
# 1      1        Kenton Keith      New Mexico State  Big West  11  109   865
# 2      2     Levron Williams               Indiana   Big Ten  10  116   937
# 3      3  Correll Buckhalter              Nebraska    Big 12  11  106   835
# 4      4     Deonce Whitaker        San Jose State       WAC  10  224  1614
# ..   ...                 ...                   ...       ...  ..  ...   ...
# 257  245    Josh Blankenship                 Tulsa       WAC  12   81   -19
# 258  246           Andy Sahm   Bowling Green State       MAC  11   81   -76
# 259  247       Philip Rivers  North Carolina State       ACC  11   73   -68
# 260  248           D. Bryant                  Duke       ACC  11   79   -67
# 261  249      Jason McKinley               Houston      CUSA  11   73  -131
#
#       Avg  TD  Rec  Plays
# 0     Avg  TD  Rec  Plays
# 1     7.5   4    6    115
# 2     6.9  10   20    136
# 3     7.5   8    5    111
# 4     7.1  16    3    227
# ..    ...  ..  ...    ...
# 257  -0.2   1          81
# 258  -0.9   3          81
# 259  -0.9   3    1     74
# 260  -0.8   2    2     81
# 261  -1.8   1          73
#
# [262 rows x 11 columns]

# %%
df_new=df.drop(columns = 'Rk')

# %%
df_new=df_new.drop(0)
df_new
# Out:
#                  Player                  School      Conf   G  Att   Yds  \
# 1          Kenton Keith        New Mexico State  Big West  11  109   865
# 2       Levron Williams                 Indiana   Big Ten  10  116   937
# 3    Correll Buckhalter                Nebraska    Big 12  11  106   835
# 4       Deonce Whitaker          San Jose State       WAC  10  224  1614
# 5           Dwone Hicks  Middle Tennessee State       Ind  11  186  1458
# ..                  ...                     ...       ...  ..  ...   ...
# 257    Josh Blankenship                   Tulsa       WAC  12   81   -19
# 258           Andy Sahm     Bowling Green State       MAC  11   81   -76
# 259       Philip Rivers    North Carolina State       ACC  11   73   -68
# 260           D. Bryant                    Duke       ACC  11   79   -67
# 261      Jason McKinley                 Houston      CUSA  11   73  -131
#
#       Avg  TD Rec Plays
# 1     7.5   4   6   115
# 2     6.9  10  20   136
# 3     7.5   8   5   111
# 4     7.1  16   3   227
# 5     7.1  21  19   205
# ..    ...  ..  ..   ...
# 257  -0.2   1        81
# 258  -0.9   3        81
# 259  -0.9   3   1    74
# 260  -0.8   2   2    81
# 261  -1.8   1        73
#
# [261 rows x 10 columns]

# %%
df_new['Player'] = df_new['Player'].str.replace('*', '')
df_new = df_new[df_new['Player'] != 'Player']

df_new
# Out:
# <ipython-input-76-8c6faff15222>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_new['Player'] = df_new['Player'].str.replace('*', '')
#                  Player                  School      Conf   G  Att   Yds  \
# 1          Kenton Keith        New Mexico State  Big West  11  109   865
# 2       Levron Williams                 Indiana   Big Ten  10  116   937
# 3    Correll Buckhalter                Nebraska    Big 12  11  106   835
# 4       Deonce Whitaker          San Jose State       WAC  10  224  1614
# 5           Dwone Hicks  Middle Tennessee State       Ind  11  186  1458
# ..                  ...                     ...       ...  ..  ...   ...
# 257    Josh Blankenship                   Tulsa       WAC  12   81   -19
# 258           Andy Sahm     Bowling Green State       MAC  11   81   -76
# 259       Philip Rivers    North Carolina State       ACC  11   73   -68
# 260           D. Bryant                    Duke       ACC  11   79   -67
# 261      Jason McKinley                 Houston      CUSA  11   73  -131
#
#       Avg  TD Rec Plays
# 1     7.5   4   6   115
# 2     6.9  10  20   136
# 3     7.5   8   5   111
# 4     7.1  16   3   227
# 5     7.1  21  19   205
# ..    ...  ..  ..   ...
# 257  -0.2   1        81
# 258  -0.9   3        81
# 259  -0.9   3   1    74
# 260  -0.8   2   2    81
# 261  -1.8   1        73
#
# [249 rows x 10 columns]

# %%
df_new.to_csv('./rushing/2000.csv')

# %% [markdown]
# ### 2001

# %%
url='https://www.sports-reference.com/cfb/years/2001-rushing.html'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[1]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Rk"
# 2:"Player"
# 3:"School"
# 4:"Conf"
# 5:"G"
# 6:"Att"
# 7:"Yds"
# 8:"Avg"
# 9:"TD"
# 10:"Rec"
# 11:"Yds"
# 12:"Avg"
# 13:"TD"
# 14:"Plays"
# 15:"Yds"
# 16:"Avg"
# 17:"TD"

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=17:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df
# Out:
#       Rk          Player          School      Conf   G  Att   Yds   Avg  TD  \
# 0     Rk          Player          School      Conf   G  Att   Yds   Avg  TD
# 1      1  Santonio Beard         Alabama       SEC   8   77   641   8.2   4
# 2      2     Luke Staley   Brigham Young       MWC  11  196  1930   8.5  28
# 3      3      Matt Jones        Arkansas       SEC   8   74   613   8.1   5
# 4      4   Leonard Henry   East Carolina      CUSA  11  184  1642   7.8  18
# ..   ...             ...             ...       ...  ..  ...   ...   ...  ..
# 265  253     Greg Zolman      Vanderbilt       SEC  11   69    -9  -0.1   5
# 266  254   Casey Bramlet         Wyoming       MWC  11   89   -22  -0.2   6
# 267  255    Jeff Smoker*  Michigan State   Big Ten  11   81   -58  -0.7   2
# 268  256      Ryan Cubit         Rutgers  Big East  11   86   -99  -1.2   0
# 269  257    Brock Nutter            Troy       Ind  11   84  -203  -2.4   2
#
#      Rec  Plays
# 0    Rec  Plays
# 1      1     78
# 2     32    228
# 3      2     76
# 4     26    210
# ..   ...    ...
# 265    1     70
# 266    1     90
# 267          81
# 268          86
# 269          84
#
# [270 rows x 11 columns]

# %%
df_new=df.drop(columns = 'Rk')

# %%
df_new=df_new.drop(0)
df_new
# Out:
#              Player                  School      Conf   G  Att   Yds   Avg  \
# 1    Santonio Beard                 Alabama       SEC   8   77   641   8.2
# 2       Luke Staley           Brigham Young       MWC  11  196  1930   8.5
# 3        Matt Jones                Arkansas       SEC   8   74   613   8.1
# 4     Leonard Henry           East Carolina      CUSA  11  184  1642   7.8
# 5       Reshard Lee  Middle Tennessee State  Sun Belt  11  108   877   7.5
# ..              ...                     ...       ...  ..  ...   ...   ...
# 265     Greg Zolman              Vanderbilt       SEC  11   69    -9  -0.1
# 266   Casey Bramlet                 Wyoming       MWC  11   89   -22  -0.2
# 267    Jeff Smoker*          Michigan State   Big Ten  11   81   -58  -0.7
# 268      Ryan Cubit                 Rutgers  Big East  11   86   -99  -1.2
# 269    Brock Nutter                    Troy       Ind  11   84  -203  -2.4
#
#      TD Rec Plays
# 1     4   1    78
# 2    28  32   228
# 3     5   2    76
# 4    18  26   210
# 5     4   9   117
# ..   ..  ..   ...
# 265   5   1    70
# 266   6   1    90
# 267   2        81
# 268   0        86
# 269   2        84
#
# [269 rows x 10 columns]

# %%
df_new['Player'] = df_new['Player'].str.replace('*', '')
df_new = df_new[df_new['Player'] != 'Player']

df_new
# Out:
# <ipython-input-84-8c6faff15222>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_new['Player'] = df_new['Player'].str.replace('*', '')
#              Player                  School      Conf   G  Att   Yds   Avg  \
# 1    Santonio Beard                 Alabama       SEC   8   77   641   8.2
# 2       Luke Staley           Brigham Young       MWC  11  196  1930   8.5
# 3        Matt Jones                Arkansas       SEC   8   74   613   8.1
# 4     Leonard Henry           East Carolina      CUSA  11  184  1642   7.8
# 5       Reshard Lee  Middle Tennessee State  Sun Belt  11  108   877   7.5
# ..              ...                     ...       ...  ..  ...   ...   ...
# 265     Greg Zolman              Vanderbilt       SEC  11   69    -9  -0.1
# 266   Casey Bramlet                 Wyoming       MWC  11   89   -22  -0.2
# 267     Jeff Smoker          Michigan State   Big Ten  11   81   -58  -0.7
# 268      Ryan Cubit                 Rutgers  Big East  11   86   -99  -1.2
# 269    Brock Nutter                    Troy       Ind  11   84  -203  -2.4
#
#      TD Rec Plays
# 1     4   1    78
# 2    28  32   228
# 3     5   2    76
# 4    18  26   210
# 5     4   9   117
# ..   ..  ..   ...
# 265   5   1    70
# 266   6   1    90
# 267   2        81
# 268   0        86
# 269   2        84
#
# [257 rows x 10 columns]

# %%
df_new.to_csv('./rushing/2001.csv')

# %% [markdown]
# ### 2002

# %%
url='https://www.sports-reference.com/cfb/years/2002-rushing.html'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[1]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Rk"
# 2:"Player"
# 3:"School"
# 4:"Conf"
# 5:"G"
# 6:"Att"
# 7:"Yds"
# 8:"Avg"
# 9:"TD"
# 10:"Rec"
# 11:"Yds"
# 12:"Avg"
# 13:"TD"
# 14:"Plays"
# 15:"Yds"
# 16:"Avg"
# 17:"TD"

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=17:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df
# Out:
#       Rk              Player      School     Conf   G  Att   Yds   Avg  TD  \
# 0     Rk              Player      School     Conf   G  Att   Yds   Avg  TD
# 1      1      Larry Johnson*  Penn State  Big Ten  13  271  2436   7.8  23
# 2      2       Joshua Cribbs  Kent State      MAC  10  137  1057   7.7  10
# 3      3    Dominique Dorsey        UNLV      MWC  12   78   575   7.3   3
# 4      4         Larry Croom        UNLV      MWC  12   84   872   8.4   6
# ..   ...                 ...         ...      ...  ..  ...   ...   ...  ..
# 246  235         Aaron Karas      Baylor   Big 12  11   95    17   0.2   2
# 247  236     Darrell Hackney         UAB     CUSA  11   85   -14  -0.2   2
# 248  237  Ben Roethlisberger  Miami (OH)      MAC  12   82   -54  -0.7   1
# 249  238    Kliff Kingsbury*  Texas Tech   Big 12  14  102  -114  -1.1   2
# 250  239       Cody Pickett*  Washington   Pac-10  13   86  -193  -2.2   3
#
#      Rec  Plays
# 0    Rec  Plays
# 1     41    312
# 2           137
# 3      1     79
# 4     20    104
# ..   ...    ...
# 246    1     96
# 247          85
# 248          82
# 249    1    103
# 250    1     87
#
# [251 rows x 11 columns]

# %%
df_new=df.drop(columns = 'Rk')

# %%
df_new=df_new.drop(0)
df_new
# Out:
#                  Player      School     Conf   G  Att   Yds   Avg  TD Rec  \
# 1        Larry Johnson*  Penn State  Big Ten  13  271  2436   7.8  23  41
# 2         Joshua Cribbs  Kent State      MAC  10  137  1057   7.7  10
# 3      Dominique Dorsey        UNLV      MWC  12   78   575   7.3   3   1
# 4           Larry Croom        UNLV      MWC  12   84   872   8.4   6  20
# 5        Shaud Williams     Alabama      SEC  13  130  1149   7.6   5  21
# ..                  ...         ...      ...  ..  ...   ...   ...  ..  ..
# 246         Aaron Karas      Baylor   Big 12  11   95    17   0.2   2   1
# 247     Darrell Hackney         UAB     CUSA  11   85   -14  -0.2   2
# 248  Ben Roethlisberger  Miami (OH)      MAC  12   82   -54  -0.7   1
# 249    Kliff Kingsbury*  Texas Tech   Big 12  14  102  -114  -1.1   2   1
# 250       Cody Pickett*  Washington   Pac-10  13   86  -193  -2.2   3   1
#
#     Plays
# 1     312
# 2     137
# 3      79
# 4     104
# 5     151
# ..    ...
# 246    96
# 247    85
# 248    82
# 249   103
# 250    87
#
# [250 rows x 10 columns]

# %%
df_new['Player'] = df_new['Player'].str.replace('*', '')
df_new = df_new[df_new['Player'] != 'Player']

df_new
# Out:
# <ipython-input-92-8c6faff15222>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_new['Player'] = df_new['Player'].str.replace('*', '')
#                  Player      School     Conf   G  Att   Yds   Avg  TD Rec  \
# 1         Larry Johnson  Penn State  Big Ten  13  271  2436   7.8  23  41
# 2         Joshua Cribbs  Kent State      MAC  10  137  1057   7.7  10
# 3      Dominique Dorsey        UNLV      MWC  12   78   575   7.3   3   1
# 4           Larry Croom        UNLV      MWC  12   84   872   8.4   6  20
# 5        Shaud Williams     Alabama      SEC  13  130  1149   7.6   5  21
# ..                  ...         ...      ...  ..  ...   ...   ...  ..  ..
# 246         Aaron Karas      Baylor   Big 12  11   95    17   0.2   2   1
# 247     Darrell Hackney         UAB     CUSA  11   85   -14  -0.2   2
# 248  Ben Roethlisberger  Miami (OH)      MAC  12   82   -54  -0.7   1
# 249     Kliff Kingsbury  Texas Tech   Big 12  14  102  -114  -1.1   2   1
# 250        Cody Pickett  Washington   Pac-10  13   86  -193  -2.2   3   1
#
#     Plays
# 1     312
# 2     137
# 3      79
# 4     104
# 5     151
# ..    ...
# 246    96
# 247    85
# 248    82
# 249   103
# 250    87
#
# [239 rows x 10 columns]

# %%
df_new.to_csv('./rushing/2002.csv')

# %% [markdown]
# ### 2003

# %%
url='https://www.sports-reference.com/cfb/years/2003-rushing.html'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[1]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Rk"
# 2:"Player"
# 3:"School"
# 4:"Conf"
# 5:"G"
# 6:"Att"
# 7:"Yds"
# 8:"Avg"
# 9:"TD"
# 10:"Rec"
# 11:"Yds"
# 12:"Avg"
# 13:"TD"
# 14:"Plays"
# 15:"Yds"
# 16:"Avg"
# 17:"TD"

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=17:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df
# Out:
#       Rk               Player             School     Conf   G  Att   Yds  \
# 0     Rk               Player             School     Conf   G  Att   Yds
# 1      1         Vince Young*              Texas   Big 12  12  135   998
# 2      2          Matt Jones*           Arkansas      SEC  13   96   719
# 3      3          Thomas Lott               Rice      WAC  11   98   729
# 4      4    Laurence Maroney*          Minnesota  Big Ten  13  162  1132
# ..   ...                  ...                ...      ...  ..  ...   ...
# 280  267  Charlie Whitehurst*            Clemson      ACC  13   92    49
# 281  268       Matt LoVecchio            Indiana  Big Ten  11   97     7
# 282  269         Cody Pickett         Washington   Pac-10  12   80   -61
# 283  270           Josh Haldi  Northern Illinois      MAC  12   75   -65
# 284  271        Casey Bramlet            Wyoming      MWC  12   98  -101
#
#       Avg  TD  Rec  Plays
# 0     Avg  TD  Rec  Plays
# 1     7.4  11         135
# 2     7.4   8    1     97
# 3     7.1   3    4    102
# 4     6.9  10    1    163
# ..    ...  ..  ...    ...
# 280   0.5   4          92
# 281   0.1   2    1     98
# 282  -0.8   3          80
# 283  -0.9   3    0     75
# 284  -1.0   3          98
#
# [285 rows x 11 columns]

# %%
df_new=df.drop(columns = 'Rk')

# %%
df_new=df_new.drop(0)
df_new
# Out:
#                   Player             School     Conf   G  Att   Yds   Avg  TD  \
# 1           Vince Young*              Texas   Big 12  12  135   998   7.4  11
# 2            Matt Jones*           Arkansas      SEC  13   96   719   7.4   8
# 3            Thomas Lott               Rice      WAC  11   98   729   7.1   3
# 4      Laurence Maroney*          Minnesota  Big Ten  13  162  1132   6.9  10
# 5        Ciatrick Fason*            Florida      SEC  13   84   725   7.6   6
# ..                   ...                ...      ...  ..  ...   ...   ...  ..
# 280  Charlie Whitehurst*            Clemson      ACC  13   92    49   0.5   4
# 281       Matt LoVecchio            Indiana  Big Ten  11   97     7   0.1   2
# 282         Cody Pickett         Washington   Pac-10  12   80   -61  -0.8   3
# 283           Josh Haldi  Northern Illinois      MAC  12   75   -65  -0.9   3
# 284        Casey Bramlet            Wyoming      MWC  12   98  -101  -1.0   3
#
#     Rec Plays
# 1         135
# 2     1    97
# 3     4   102
# 4     1   163
# 5    11    95
# ..   ..   ...
# 280        92
# 281   1    98
# 282        80
# 283   0    75
# 284        98
#
# [284 rows x 10 columns]

# %%
df_new['Player'] = df_new['Player'].str.replace('*', '')
df_new = df_new[df_new['Player'] != 'Player']

df_new
# Out:
# <ipython-input-100-8c6faff15222>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_new['Player'] = df_new['Player'].str.replace('*', '')
#                  Player             School     Conf   G  Att   Yds   Avg  TD  \
# 1           Vince Young              Texas   Big 12  12  135   998   7.4  11
# 2            Matt Jones           Arkansas      SEC  13   96   719   7.4   8
# 3           Thomas Lott               Rice      WAC  11   98   729   7.1   3
# 4      Laurence Maroney          Minnesota  Big Ten  13  162  1132   6.9  10
# 5        Ciatrick Fason            Florida      SEC  13   84   725   7.6   6
# ..                  ...                ...      ...  ..  ...   ...   ...  ..
# 280  Charlie Whitehurst            Clemson      ACC  13   92    49   0.5   4
# 281      Matt LoVecchio            Indiana  Big Ten  11   97     7   0.1   2
# 282        Cody Pickett         Washington   Pac-10  12   80   -61  -0.8   3
# 283          Josh Haldi  Northern Illinois      MAC  12   75   -65  -0.9   3
# 284       Casey Bramlet            Wyoming      MWC  12   98  -101  -1.0   3
#
#     Rec Plays
# 1         135
# 2     1    97
# 3     4   102
# 4     1   163
# 5    11    95
# ..   ..   ...
# 280        92
# 281   1    98
# 282        80
# 283   0    75
# 284        98
#
# [271 rows x 10 columns]

# %%
df_new.to_csv('./rushing/2003.csv')

# %% [markdown]
# ### 2004

# %%
url='https://www.sports-reference.com/cfb/years/2004-rushing.html'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[1]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Rk"
# 2:"Player"
# 3:"School"
# 4:"Conf"
# 5:"G"
# 6:"Att"
# 7:"Yds"
# 8:"Avg"
# 9:"TD"
# 10:"Rec"
# 11:"Yds"
# 12:"Avg"
# 13:"TD"
# 14:"Plays"
# 15:"Yds"
# 16:"Avg"
# 17:"TD"

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=17:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df
# Out:
#       Rk            Player          School     Conf   G  Att   Yds   Avg  TD  \
# 0     Rk            Player          School     Conf   G  Att   Yds   Avg  TD
# 1      1      Deandra Cobb  Michigan State  Big Ten  12   96   738   7.2   4
# 2      2        Matt Jones        Arkansas      SEC  11   83   622   7.5   6
# 3      3      Drew Stanton  Michigan State  Big Ten  10   96   709   7.2   6
# 4      4   J.J. Arrington*      California   Pac-10  12  289  2139   6.9  15
# ..   ...               ...             ...      ...  ..  ...   ...   ...  ..
# 276  263         John Beck   Brigham Young      MWC  11   90   -36  -0.4   0
# 277  264  Darrell Hackney*             UAB     CUSA  12   81   -44  -0.5   2
# 278  265    Mike Schneider            Duke      ACC  11   72   -44  -0.6   2
# 279  266        Drew Tate*            Iowa  Big Ten  12   89   -68  -0.8   2
# 280  267   Derek Anderson*    Oregon State   Pac-10  12   75  -152  -2.0   2
#
#      Rec  Plays
# 0    Rec  Plays
# 1      7    103
# 2            83
# 3      2     98
# 4     21    310
# ..   ...    ...
# 276          90
# 277          81
# 278    1     73
# 279    1     90
# 280          75
#
# [281 rows x 11 columns]

# %%
df_new=df.drop(columns = 'Rk')

# %%
df_new=df_new.drop(0)
df_new
# Out:
#                Player          School     Conf   G  Att   Yds   Avg  TD Rec  \
# 1        Deandra Cobb  Michigan State  Big Ten  12   96   738   7.2   4   7
# 2          Matt Jones        Arkansas      SEC  11   83   622   7.5   6
# 3        Drew Stanton  Michigan State  Big Ten  10   96   709   7.2   6   2
# 4     J.J. Arrington*      California   Pac-10  12  289  2139   6.9  15  21
# 5    Leon Washington*   Florida State      ACC  10  138  1041   6.8   7  14
# ..                ...             ...      ...  ..  ...   ...   ...  ..  ..
# 276         John Beck   Brigham Young      MWC  11   90   -36  -0.4   0
# 277  Darrell Hackney*             UAB     CUSA  12   81   -44  -0.5   2
# 278    Mike Schneider            Duke      ACC  11   72   -44  -0.6   2   1
# 279        Drew Tate*            Iowa  Big Ten  12   89   -68  -0.8   2   1
# 280   Derek Anderson*    Oregon State   Pac-10  12   75  -152  -2.0   2
#
#     Plays
# 1     103
# 2      83
# 3      98
# 4     310
# 5     152
# ..    ...
# 276    90
# 277    81
# 278    73
# 279    90
# 280    75
#
# [280 rows x 10 columns]

# %%
df_new['Player'] = df_new['Player'].str.replace('*', '')
df_new = df_new[df_new['Player'] != 'Player']

df_new
# Out:
# <ipython-input-108-8c6faff15222>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_new['Player'] = df_new['Player'].str.replace('*', '')
#               Player          School     Conf   G  Att   Yds   Avg  TD Rec  \
# 1       Deandra Cobb  Michigan State  Big Ten  12   96   738   7.2   4   7
# 2         Matt Jones        Arkansas      SEC  11   83   622   7.5   6
# 3       Drew Stanton  Michigan State  Big Ten  10   96   709   7.2   6   2
# 4     J.J. Arrington      California   Pac-10  12  289  2139   6.9  15  21
# 5    Leon Washington   Florida State      ACC  10  138  1041   6.8   7  14
# ..               ...             ...      ...  ..  ...   ...   ...  ..  ..
# 276        John Beck   Brigham Young      MWC  11   90   -36  -0.4   0
# 277  Darrell Hackney             UAB     CUSA  12   81   -44  -0.5   2
# 278   Mike Schneider            Duke      ACC  11   72   -44  -0.6   2   1
# 279        Drew Tate            Iowa  Big Ten  12   89   -68  -0.8   2   1
# 280   Derek Anderson    Oregon State   Pac-10  12   75  -152  -2.0   2
#
#     Plays
# 1     103
# 2      83
# 3      98
# 4     310
# 5     152
# ..    ...
# 276    90
# 277    81
# 278    73
# 279    90
# 280    75
#
# [267 rows x 10 columns]

# %%
df_new.to_csv('./rushing/2004.csv')

# %% [markdown]
# ### 2005

# %%
url='https://www.sports-reference.com/cfb/years/2005-rushing.html'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[1]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Rk"
# 2:"Player"
# 3:"School"
# 4:"Conf"
# 5:"G"
# 6:"Att"
# 7:"Yds"
# 8:"Avg"
# 9:"TD"
# 10:"Rec"
# 11:"Yds"
# 12:"Avg"
# 13:"TD"
# 14:"Plays"
# 15:"Yds"
# 16:"Avg"
# 17:"TD"

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=17:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df
# Out:
#       Rk             Player                  School      Conf   G  Att   Yds  \
# 0     Rk             Player                  School      Conf   G  Att   Yds
# 1      1       Reggie Bush*                     USC    Pac-10  13  200  2218
# 2      2  George Stripling*              Louisville  Big East  12   79   635
# 3      3    Justin Forsett*              California    Pac-10  12  132  1067
# 4      4         Nate Ilaoa                  Hawaii       WAC  12   85   917
# ..   ...                ...                     ...       ...  ..  ...   ...
# 276  263    Perry Patterson                Syracuse  Big East  11   72   -37
# 277  264         Zac Taylor                Nebraska    Big 12  12   76   -45
# 278  265         Joey Lynch              Ball State       MAC  11   86  -106
# 279  266        Clint Marks  Middle Tennessee State  Sun Belt  11   69  -111
# 280  267        Tyler Palko                    Pitt  Big East  11   70  -139
#
#       Avg  TD  Rec  Plays
# 0     Avg  TD  Rec  Plays
# 1     9.4  18   37    237
# 2     7.9   7    1     80
# 3     7.7   6    7    139
# 4     7.6   7   36    121
# ..    ...  ..  ...    ...
# 276  -0.5   3          72
# 277  -0.6   1    1     77
# 278  -1.2   0    1     87
# 279  -1.6   3    1     70
# 280  -2.0   6          70
#
# [281 rows x 11 columns]

# %%
df_new=df.drop(columns = 'Rk')

# %%
df_new=df_new.drop(0)
df_new
# Out:
#                 Player                  School      Conf   G  Att   Yds   Avg  \
# 1         Reggie Bush*                     USC    Pac-10  13  200  2218   9.4
# 2    George Stripling*              Louisville  Big East  12   79   635   7.9
# 3      Justin Forsett*              California    Pac-10  12  132  1067   7.7
# 4           Nate Ilaoa                  Hawaii       WAC  12   85   917   7.6
# 5      Jamaal Charles*                   Texas    Big 12  13  119  1035   7.8
# ..                 ...                     ...       ...  ..  ...   ...   ...
# 276    Perry Patterson                Syracuse  Big East  11   72   -37  -0.5
# 277         Zac Taylor                Nebraska    Big 12  12   76   -45  -0.6
# 278         Joey Lynch              Ball State       MAC  11   86  -106  -1.2
# 279        Clint Marks  Middle Tennessee State  Sun Belt  11   69  -111  -1.6
# 280        Tyler Palko                    Pitt  Big East  11   70  -139  -2.0
#
#      TD Rec Plays
# 1    18  37   237
# 2     7   1    80
# 3     6   7   139
# 4     7  36   121
# 5    13  14   133
# ..   ..  ..   ...
# 276   3        72
# 277   1   1    77
# 278   0   1    87
# 279   3   1    70
# 280   6        70
#
# [280 rows x 10 columns]

# %%
df_new['Player'] = df_new['Player'].str.replace('*', '')
df_new = df_new[df_new['Player'] != 'Player']

df_new
# Out:
# <ipython-input-116-8c6faff15222>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_new['Player'] = df_new['Player'].str.replace('*', '')
#                Player                  School      Conf   G  Att   Yds   Avg  \
# 1         Reggie Bush                     USC    Pac-10  13  200  2218   9.4
# 2    George Stripling              Louisville  Big East  12   79   635   7.9
# 3      Justin Forsett              California    Pac-10  12  132  1067   7.7
# 4          Nate Ilaoa                  Hawaii       WAC  12   85   917   7.6
# 5      Jamaal Charles                   Texas    Big 12  13  119  1035   7.8
# ..                ...                     ...       ...  ..  ...   ...   ...
# 276   Perry Patterson                Syracuse  Big East  11   72   -37  -0.5
# 277        Zac Taylor                Nebraska    Big 12  12   76   -45  -0.6
# 278        Joey Lynch              Ball State       MAC  11   86  -106  -1.2
# 279       Clint Marks  Middle Tennessee State  Sun Belt  11   69  -111  -1.6
# 280       Tyler Palko                    Pitt  Big East  11   70  -139  -2.0
#
#      TD Rec Plays
# 1    18  37   237
# 2     7   1    80
# 3     6   7   139
# 4     7  36   121
# 5    13  14   133
# ..   ..  ..   ...
# 276   3        72
# 277   1   1    77
# 278   0   1    87
# 279   3   1    70
# 280   6        70
#
# [267 rows x 10 columns]

# %%
df_new.to_csv('./rushing/2005.csv')

# %% [markdown]
# ### 2006

# %%
url='https://www.sports-reference.com/cfb/years/2006-rushing.html'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[1]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Rk"
# 2:"Player"
# 3:"School"
# 4:"Conf"
# 5:"G"
# 6:"Att"
# 7:"Yds"
# 8:"Avg"
# 9:"TD"
# 10:"Rec"
# 11:"Yds"
# 12:"Avg"
# 13:"TD"
# 14:"Plays"
# 15:"Yds"
# 16:"Avg"
# 17:"TD"

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=17:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df
# Out:
#       Rk              Player            School      Conf   G  Att   Yds   Avg  \
# 0     Rk              Player            School      Conf   G  Att   Yds   Avg
# 1      1    Anthony Alridge*           Houston      CUSA  14   95  1233  10.8
# 2      2  Rashard Mendenhall          Illinois   Big Ten  12   78   804   8.9
# 3      3        Felix Jones*          Arkansas       SEC  14  154  1275   7.5
# 4      4         Nate Ilaoa*            Hawaii       WAC  13  131  1827   9.2
# ..   ...                 ...               ...       ...  ..  ...   ...   ...
# 250  239          Alex Brink  Washington State    Pac-10  12   78    12   0.2
# 251  240      Thaddeus Lewis              Duke       ACC  12   99   -74  -0.7
# 252   Rk              Player            School      Conf   G  Att   Yds   Avg
# 253  241      Chase Holbrook  New Mexico State       WAC  12   80   -78  -1.0
# 254  242     Perry Patterson          Syracuse  Big East  12   82  -182  -2.2
#
#      TD  Rec  Plays
# 0    TD  Rec  Plays
# 1     9   19    114
# 2     6   12     90
# 3     9   15    169
# 4    18   67    198
# ..   ..  ...    ...
# 250   3    1     79
# 251   1          99
# 252  TD  Rec  Plays
# 253   4          80
# 254   1    1     83
#
# [255 rows x 11 columns]

# %%
df_new=df.drop(columns = 'Rk')

# %%
df_new=df_new.drop(0)
df_new
# Out:
#                  Player            School      Conf   G  Att   Yds   Avg  TD  \
# 1      Anthony Alridge*           Houston      CUSA  14   95  1233  10.8   9
# 2    Rashard Mendenhall          Illinois   Big Ten  12   78   804   8.9   6
# 3          Felix Jones*          Arkansas       SEC  14  154  1275   7.5   9
# 4           Nate Ilaoa*            Hawaii       WAC  13  131  1827   9.2  18
# 5            Pat White*     West Virginia  Big East  12  165  1219   7.4  18
# ..                  ...               ...       ...  ..  ...   ...   ...  ..
# 250          Alex Brink  Washington State    Pac-10  12   78    12   0.2   3
# 251      Thaddeus Lewis              Duke       ACC  12   99   -74  -0.7   1
# 252              Player            School      Conf   G  Att   Yds   Avg  TD
# 253      Chase Holbrook  New Mexico State       WAC  12   80   -78  -1.0   4
# 254     Perry Patterson          Syracuse  Big East  12   82  -182  -2.2   1
#
#      Rec  Plays
# 1     19    114
# 2     12     90
# 3     15    169
# 4     67    198
# 5           165
# ..   ...    ...
# 250    1     79
# 251          99
# 252  Rec  Plays
# 253          80
# 254    1     83
#
# [254 rows x 10 columns]

# %%
df_new['Player'] = df_new['Player'].str.replace('*', '')
df_new = df_new[df_new['Player'] != 'Player']

df_new
# Out:
# <ipython-input-124-8c6faff15222>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_new['Player'] = df_new['Player'].str.replace('*', '')
#                  Player            School      Conf   G  Att   Yds   Avg  TD  \
# 1       Anthony Alridge           Houston      CUSA  14   95  1233  10.8   9
# 2    Rashard Mendenhall          Illinois   Big Ten  12   78   804   8.9   6
# 3           Felix Jones          Arkansas       SEC  14  154  1275   7.5   9
# 4            Nate Ilaoa            Hawaii       WAC  13  131  1827   9.2  18
# 5             Pat White     West Virginia  Big East  12  165  1219   7.4  18
# ..                  ...               ...       ...  ..  ...   ...   ...  ..
# 249         Caleb Hanie    Colorado State       MWC  12  108    55   0.5   4
# 250          Alex Brink  Washington State    Pac-10  12   78    12   0.2   3
# 251      Thaddeus Lewis              Duke       ACC  12   99   -74  -0.7   1
# 253      Chase Holbrook  New Mexico State       WAC  12   80   -78  -1.0   4
# 254     Perry Patterson          Syracuse  Big East  12   82  -182  -2.2   1
#
#     Rec Plays
# 1    19   114
# 2    12    90
# 3    15   169
# 4    67   198
# 5         165
# ..   ..   ...
# 249       108
# 250   1    79
# 251        99
# 253        80
# 254   1    83
#
# [242 rows x 10 columns]

# %%
df_new.to_csv('./rushing/2006.csv')
